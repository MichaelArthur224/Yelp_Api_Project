# %%
import json
import pandas as pd
from yelpapi import YelpAPI
import json
import os

# %%
# !pip install yelpapi
# Out:
# Requirement already satisfied: yelpapi in c:\users\michael\anaconda3\envs\dojo-env\lib\site-packages (2.5.0)
# Requirement already satisfied: requests in c:\users\michael\anaconda3\envs\dojo-env\lib\site-packages (from yelpapi) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\michael\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\michael\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\michael\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\michael\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (3.4)

# %%
with open('/Users/Michael/.secret/yelp_api.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
location = 'Fresno, CA 93704'
term = 'pizza'

# %%
FOLDER ='Data/'
os.makedirs(FOLDER,exist_ok=True)

# %%
location.split(',')[0]
# Out:
# 'Fresno'

# %%
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"
JSON_FILE
# Out:
# 'Data/Fresno-pizza.json'

# %%
#Check 
file_exists = os.path.isfile(JSON_FILE)
 
if file_exists ==False:

    folder = os.path.dirname(JSON_FILE)

    if len(folder)>0:
        os.makedirs(folder,exist_ok=True)
        
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    with open(JSON_FILE,'w')as f:
        json.dump([],f)

else:
       print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Fresno-pizza.json not found. Saving empty list to file.

# %%
results = yelp_api.search_query(term=term,location = location)

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['businesses']
# Out:
# [{'id': 'Wq4vY9X3k6jgLaadvRVxyg',
#   'alias': 'douggy-fresh-pizza-fresno',
#   'name': 'Douggy Fresh Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2TiUdH3o15xf7Agx8YgG7Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/douggy-fresh-pizza-fresno?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 127,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 36.76456, 'longitude': -119.8088},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '1585 N Palm Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Fresno',
#    'zip_code': '93728',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1585 N Palm Ave', 'Fresno, CA 93728']},
#   'phone': '+15592373800',
#   'display_phone': '(559) 237-3800',
#   'distance': 4097.525055179005},
#  {'id': '9CaD0j4poIV4tw-U-yY38w',
#   'alias': 'mama-mia-pizzaria-fresno',
#   'name': 'Mama Mia Pizzaria',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sk0x94X-u64u3TSo8gChOQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mama-mia-pizzaria-fresno?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 333,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 36.8232937646232,
#    'longitude': -119.806807411045},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '734 W Bullard Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Fresno',
#    'zip_code': '93704',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['734 W Bullard Ave', 'Fresno, CA 93704']},
#   'phone': '+15594395303',
#   'display_phone': '(559) 439-5303',
#   'distance': 2505.821715655855},
#  {'id': '7B6J9pnwWrdG8CBJ3zO6KQ',
#   'alias': '99-craft-pizza-no-title',
#   'name': '99 Craft Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YCIxQRWKemHz6rFEqKnBMg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/99-craft-pizza-no-title?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 61,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 36.85150634535241, 'longitude': -119.8033517},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '585 W Nees Ave',
#    'address2': 'Ste 123',
#    'address3': '',
#    'city': 'Fresno',
#    'zip_code': '93711',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['585 W Nees Ave', 'Ste 123', 'Fresno, CA 93711']},
#   'phone': '+15592838915',
#   'display_phone': '(559) 283-8915',
#   'distance': 5613.596878298046},
#  {'id': 'JWPLq6LSz5nrDaHLAc944Q',
#   'alias': 'more-than-pizza-fresno',
#   'name': 'More Than Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yR9rn47IcY7Yrd6QeWyeRA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/more-than-pizza-fresno?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 178,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 36.82241487334167,
#    'longitude': -119.82795454792308},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2095 W Bullard Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Fresno',
#    'zip_code': '93711',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2095 W Bullard Ave', 'Fresno, CA 93711']},
#   'phone': '+15598401564',
#   'display_phone': '(559) 840-1564',
#   'distance': 3286.5024810322516},
#  {'id': '3uBgSXc_FP1sRSKfjWExoQ',
#   'alias': 'the-curry-pizza-company-fresno',
#   'name': 'The Curry Pizza Company',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EGhe6m7FJK3_Npj2344HWQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-curry-pizza-company-fresno?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 525,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'vegetarian', 'title': 'Vegetarian'},
#    {'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 36.80812, 'longitude': -119.84822},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3173 W Shaw Ave',
#    'address2': 'Ste 103',
#    'address3': '',
#    'city': 'Fresno',
#    'zip_code': '93711',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3173 W Shaw Ave', 'Ste 103', 'Fresno, CA 93711']},
#   'phone': '+15593657000',
#   'display_phone': '(559) 365-7000',
#   'distance': 4149.776354020418},
#  {'id': 'XYbkjmCMsGI6ELZQemLKZw',
#   'alias': 'la-pizza-nostra-clovis',
#   'name': 'La Pizza Nostra',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8Ix7iO7y3UeK1NWRBRTkNw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-pizza-nostra-clovis?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 40,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 36.8018315, 'longitude': -119.7274249},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2792 Willow Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Clovis',
#    'zip_code': '93612',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2792 Willow Ave', 'Clovis, CA 93612']},
#   'phone': '+15592945952',
#   'display_phone': '(559) 294-5952',
#   'distance': 6648.725690245133},
#  {'id': 'UVW_GF1zGsKN8OBOTGQUGA',
#   'alias': 'annesso-pizzeria-fresno-2',
#   'name': 'Annesso Pizzeria',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NSbCZuKICD-sZAlV7wkaCg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/annesso-pizzeria-fresno-2?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 358,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 36.85922376493786,
#    'longitude': -119.7830944195512},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '8484 N Friant Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'Fresno',
#    'zip_code': '93720',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['8484 N Friant Rd', 'Fresno, CA 93720']},
#   'phone': '+15599818995',
#   'display_phone': '(559) 981-8995',
#   'distance': 6697.136343617232},
#  {'id': 'VontJDOok8AhBO22P5IihA',
#   'alias': '525-pizza-fresno-2',
#   'name': '525 Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rsmHZElTDrwLWCy3Np0DFg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/525-pizza-fresno-2?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 53,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'armenian', 'title': 'Armenian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 36.7863678, 'longitude': -119.8270063},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '3795 N West Ave',
#    'address2': 'Ste 104',
#    'address3': None,
#    'city': 'Fresno',
#    'zip_code': '93705',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3795 N West Ave', 'Ste 104', 'Fresno, CA 93705']},
#   'phone': '+15593751680',
#   'display_phone': '(559) 375-1680',
#   'distance': 2725.519464041083},
#  {'id': 'tCW9r2k-wP0l07gU8F8mYg',
#   'alias': 'cali-bros-pizza-no-title',
#   'name': 'Cali Bros Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NIYp7qSgOkyxI6Vui9jndA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cali-bros-pizza-no-title?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 10,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 36.82308, 'longitude': -119.84551},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '3028 W Bullard Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Fresno',
#    'zip_code': '93711',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3028 W Bullard Ave', 'Fresno, CA 93711']},
#   'phone': '+15593190500',
#   'display_phone': '(559) 319-0500',
#   'distance': 4566.833324895845},
#  {'id': 'b2udDFPOtH2zURsCVcQM9g',
#   'alias': 'mikes-pizzeria-fresno',
#   'name': "Mike's Pizzeria",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nzEs16HBLSRG_j1UzTEkGg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mikes-pizzeria-fresno?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 189,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 36.779575, 'longitude': -119.8264258},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3228 N West Ave 93705',
#    'address2': '',
#    'address3': '',
#    'city': 'Fresno',
#    'zip_code': '93705',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3228 N West Ave 93705', 'Fresno, CA 93705']},
#   'phone': '+15592292635',
#   'display_phone': '(559) 229-2635',
#   'distance': 3199.781211531216},
#  {'id': 'sTQyBE8ZZOjdJzyGjG7Oyg',
#   'alias': 'angelas-italian-restaurant-fresno',
#   'name': "Angela's Italian Restaurant",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yqfW3w1K48-SchaOhAh47g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/angelas-italian-restaurant-fresno?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 124,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 36.8131166270708,
#    'longitude': -119.791806666667},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '5251 N Blackstone Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Fresno',
#    'zip_code': '93710',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['5251 N Blackstone Ave', 'Fresno, CA 93710']},
#   'phone': '+15593745390',
#   'display_phone': '(559) 374-5390',
#   'distance': 1645.991131214772},
#  {'id': 'ZGmYRLSi2GngdrgjfKaORQ',
#   'alias': 'richies-pizza-and-hot-dogs-fresno',
#   'name': "Richie's Pizza & Hot Dogs",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gGRTOeXMSCG__fSC9-spfw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/richies-pizza-and-hot-dogs-fresno?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 317,
#   'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 36.7576313763857,
#    'longitude': -119.800757691264},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '844 E Olive',
#    'address2': '',
#    'address3': '',
#    'city': 'Fresno',
#    'zip_code': '93727',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['844 E Olive', 'Fresno, CA 93727']},
#   'phone': '+15594410067',
#   'display_phone': '(559) 441-0067',
#   'distance': 4837.217947797168},
#  {'id': 'xiPYoKcZ-QacPjrvUFRkpQ',
#   'alias': 'the-annex-kitchen-fresno-2',
#   'name': 'The Annex Kitchen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kng7_zAeck9p8GTkG-SlRA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-annex-kitchen-fresno-2?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 1452,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 36.80758, 'longitude': -119.83229},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '2257 W Shaw Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Fresno',
#    'zip_code': '93711',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2257 W Shaw Ave', 'Fresno, CA 93711']},
#   'phone': '+15592488512',
#   'display_phone': '(559) 248-8512',
#   'distance': 2750.675699991099},
#  {'id': 'lHg_LTMOn_PpPKrsazeiZQ',
#   'alias': 'chicagos-pizza-with-a-twist-fresno-4',
#   'name': "Chicago's Pizza With A Twist",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/G2TT2PnoEbS26jCqZe0Umw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chicagos-pizza-with-a-twist-fresno-4?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 164,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'vegan', 'title': 'Vegan'},
#    {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 36.809290606212876,
#    'longitude': -119.84517914325029},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3050 W Shaw Ave',
#    'address2': 'Ste 105',
#    'address3': '',
#    'city': 'Fresno',
#    'zip_code': '93711',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3050 W Shaw Ave', 'Ste 105', 'Fresno, CA 93711']},
#   'phone': '+15592773737',
#   'display_phone': '(559) 277-3737',
#   'distance': 3911.465976984124},
#  {'id': 'YcNQMo18wgEMBopgBAkH_g',
#   'alias': 'popolos-pizza-fresno',
#   'name': "Popolo's Pizza",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/upQTwqAvhTe14S2FVc_F6Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/popolos-pizza-fresno?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 338,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 36.8516087986778,
#    'longitude': -119.807144271164},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '7835 N Palm Ave',
#    'address2': 'Ste 106',
#    'address3': '',
#    'city': 'Fresno',
#    'zip_code': '93711',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['7835 N Palm Ave', 'Ste 106', 'Fresno, CA 93711']},
#   'phone': '+15594356775',
#   'display_phone': '(559) 435-6775',
#   'distance': 5639.780396461538},
#  {'id': '-KmLS-rirOFHFuFuUUf7Sw',
#   'alias': 'pieology-pizzeria-fresno-3',
#   'name': 'Pieology Pizzeria Fig Garden, Fresno, CA',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tnspfJwUHH9ZwZ7K3kbiNw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pieology-pizzeria-fresno-3?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 281,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 36.80964, 'longitude': -119.80789099969651},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '5068 N Palm Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Fresno',
#    'zip_code': '93704',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['5068 N Palm Ave', 'Fresno, CA 93704']},
#   'phone': '+15592252574',
#   'display_phone': '(559) 225-2574',
#   'distance': 1072.2715033439263},
#  {'id': 'gqhtfmrjMfXZaKbV0mKutw',
#   'alias': 'south-of-shaw-beer-company-fresno',
#   'name': 'South Of Shaw Beer Company',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/U_E6J49G1lb4imZnA1I7DA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/south-of-shaw-beer-company-fresno?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 75,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'brewpubs', 'title': 'Brewpubs'},
#    {'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 36.740603, 'longitude': -119.7999},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1755 Broadway St',
#    'address2': 'Ste 107',
#    'address3': None,
#    'city': 'Fresno',
#    'zip_code': '93721',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1755 Broadway St', 'Ste 107', 'Fresno, CA 93721']},
#   'phone': '+15597249356',
#   'display_phone': '(559) 724-9356',
#   'distance': 6722.734739098147},
#  {'id': '990vMldBdVbb4nY2JpJ3jg',
#   'alias': 'mountain-mikes-pizza-fallbrook',
#   'name': "Mountain Mike's Pizza",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/f8fUxJWNqYWafkIOjSE6bQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mountain-mikes-pizza-fallbrook?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 124,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 33.37233876, 'longitude': -117.25557119},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1125 S Mission Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'Fallbrook',
#    'zip_code': '92028',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1125 S Mission Rd', 'Fallbrook, CA 92028']},
#   'phone': '+17606450505',
#   'display_phone': '(760) 645-0505',
#   'distance': 2973.0045753399145},
#  {'id': 'dRKziMDjZQlzUUIZqI76bQ',
#   'alias': 'pacifica-pizza-fresno-2',
#   'name': 'Pacifica Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Wl3TY4ZAwB8bGHT35rhtyQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pacifica-pizza-fresno-2?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 124,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 36.7573776245117,
#    'longitude': -119.805923461914},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '444 E Olive Ave',
#    'address2': 'Ste 101',
#    'address3': '',
#    'city': 'Fresno',
#    'zip_code': '93728',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['444 E Olive Ave', 'Ste 101', 'Fresno, CA 93728']},
#   'phone': '+15592683494',
#   'display_phone': '(559) 268-3494',
#   'distance': 4871.150637677423},
#  {'id': '8OlqbBzTXpySzmjnQttF2w',
#   'alias': 'premo-pizza-fresno',
#   'name': 'Premo Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Je-uNpqYCFqSmCbZpSYInQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/premo-pizza-fresno?adjust_creative=y4ybSBGqAgTuNzS8_6niLA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4ybSBGqAgTuNzS8_6niLA',
#   'review_count': 244,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 36.8650556, 'longitude': -119.7389849},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '8887 N Chestnut Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Fresno',
#    'zip_code': '93720',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['8887 N Chestnut Ave', 'Fresno, CA 93720']},
#   'phone': '+15592981122',
#   'display_phone': '(559) 298-1122',
#   'distance': 8991.277058703246}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                 alias  \
# 0   Wq4vY9X3k6jgLaadvRVxyg             douggy-fresh-pizza-fresno
# 1   9CaD0j4poIV4tw-U-yY38w              mama-mia-pizzaria-fresno
# 2   7B6J9pnwWrdG8CBJ3zO6KQ               99-craft-pizza-no-title
# 3   JWPLq6LSz5nrDaHLAc944Q                more-than-pizza-fresno
# 4   3uBgSXc_FP1sRSKfjWExoQ        the-curry-pizza-company-fresno
# 5   XYbkjmCMsGI6ELZQemLKZw                la-pizza-nostra-clovis
# 6   UVW_GF1zGsKN8OBOTGQUGA             annesso-pizzeria-fresno-2
# 7   VontJDOok8AhBO22P5IihA                    525-pizza-fresno-2
# 8   tCW9r2k-wP0l07gU8F8mYg              cali-bros-pizza-no-title
# 9   b2udDFPOtH2zURsCVcQM9g                 mikes-pizzeria-fresno
# 10  sTQyBE8ZZOjdJzyGjG7Oyg     angelas-italian-restaurant-fresno
# 11  ZGmYRLSi2GngdrgjfKaORQ     richies-pizza-and-hot-dogs-fresno
# 12  xiPYoKcZ-QacPjrvUFRkpQ            the-annex-kitchen-fresno-2
# 13  lHg_LTMOn_PpPKrsazeiZQ  chicagos-pizza-with-a-twist-fresno-4
# 14  YcNQMo18wgEMBopgBAkH_g                  popolos-pizza-fresno
# 15  -KmLS-rirOFHFuFuUUf7Sw            pieology-pizzeria-fresno-3
# 16  gqhtfmrjMfXZaKbV0mKutw     south-of-shaw-beer-company-fresno
# 17  990vMldBdVbb4nY2JpJ3jg        mountain-mikes-pizza-fallbrook
# 18  dRKziMDjZQlzUUIZqI76bQ               pacifica-pizza-fresno-2
# 19  8OlqbBzTXpySzmjnQttF2w                    premo-pizza-fresno
#
#                                         name  \
# 0                         Douggy Fresh Pizza
# 1                          Mama Mia Pizzaria
# 2                             99 Craft Pizza
# 3                            More Than Pizza
# 4                    The Curry Pizza Company
# 5                            La Pizza Nostra
# 6                           Annesso Pizzeria
# 7                                  525 Pizza
# 8                            Cali Bros Pizza
# 9                            Mike's Pizzeria
# 10               Angela's Italian Restaurant
# 11                 Richie's Pizza & Hot Dogs
# 12                         The Annex Kitchen
# 13              Chicago's Pizza With A Twist
# 14                            Popolo's Pizza
# 15  Pieology Pizzeria Fig Garden, Fresno, CA
# 16                South Of Shaw Beer Company
# 17                     Mountain Mike's Pizza
# 18                            Pacifica Pizza
# 19                               Premo Pizza
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/2TiUdH...      False
# 1   https://s3-media3.fl.yelpcdn.com/bphoto/sk0x94...      False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/YCIxQR...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/yR9rn4...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/EGhe6m...      False
# 5   https://s3-media4.fl.yelpcdn.com/bphoto/8Ix7iO...      False
# 6   https://s3-media4.fl.yelpcdn.com/bphoto/NSbCZu...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/rsmHZE...      False
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/NIYp7q...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/nzEs16...      False
# 10  https://s3-media3.fl.yelpcdn.com/bphoto/yqfW3w...      False
# 11  https://s3-media4.fl.yelpcdn.com/bphoto/gGRTOe...      False
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/kng7_z...      False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/G2TT2P...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/upQTwq...      False
# 15  https://s3-media4.fl.yelpcdn.com/bphoto/tnspfJ...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/U_E6J4...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/f8fUxJ...      False
# 18  https://s3-media1.fl.yelpcdn.com/bphoto/Wl3TY4...      False
# 19  https://s3-media1.fl.yelpcdn.com/bphoto/Je-uNp...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/douggy-fresh-pizza-fr...           127
# 1   https://www.yelp.com/biz/mama-mia-pizzaria-fre...           333
# 2   https://www.yelp.com/biz/99-craft-pizza-no-tit...            61
# 3   https://www.yelp.com/biz/more-than-pizza-fresn...           178
# 4   https://www.yelp.com/biz/the-curry-pizza-compa...           525
# 5   https://www.yelp.com/biz/la-pizza-nostra-clovi...            40
# 6   https://www.yelp.com/biz/annesso-pizzeria-fres...           358
# 7   https://www.yelp.com/biz/525-pizza-fresno-2?ad...            53
# 8   https://www.yelp.com/biz/cali-bros-pizza-no-ti...            10
# 9   https://www.yelp.com/biz/mikes-pizzeria-fresno...           189
# 10  https://www.yelp.com/biz/angelas-italian-resta...           124
# 11  https://www.yelp.com/biz/richies-pizza-and-hot...           317
# 12  https://www.yelp.com/biz/the-annex-kitchen-fre...          1452
# 13  https://www.yelp.com/biz/chicagos-pizza-with-a...           164
# 14  https://www.yelp.com/biz/popolos-pizza-fresno?...           338
# 15  https://www.yelp.com/biz/pieology-pizzeria-fre...           281
# 16  https://www.yelp.com/biz/south-of-shaw-beer-co...            75
# 17  https://www.yelp.com/biz/mountain-mikes-pizza-...           124
# 18  https://www.yelp.com/biz/pacifica-pizza-fresno...           124
# 19  https://www.yelp.com/biz/premo-pizza-fresno?ad...           244
#
#                                            categories  rating  \
# 0              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 1   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 2   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 3   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 4   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 5              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 6   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 7   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 8   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 9   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 10  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 11  [{'alias': 'hotdog', 'title': 'Hot Dogs'}, {'a...     4.5
# 12  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 13  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 14  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.5
# 15  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 16  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 17             [{'alias': 'pizza', 'title': 'Pizza'}]     3.0
# 18  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 19             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
#
#                                           coordinates        transactions  \
# 0      {'latitude': 36.76456, 'longitude': -119.8088}          [delivery]
# 1   {'latitude': 36.8232937646232, 'longitude': -1...  [pickup, delivery]
# 2   {'latitude': 36.85150634535241, 'longitude': -...                  []
# 3   {'latitude': 36.82241487334167, 'longitude': -...          [delivery]
# 4     {'latitude': 36.80812, 'longitude': -119.84822}  [pickup, delivery]
# 5   {'latitude': 36.8018315, 'longitude': -119.727...                  []
# 6   {'latitude': 36.85922376493786, 'longitude': -...                  []
# 7   {'latitude': 36.7863678, 'longitude': -119.827...  [pickup, delivery]
# 8     {'latitude': 36.82308, 'longitude': -119.84551}  [pickup, delivery]
# 9   {'latitude': 36.779575, 'longitude': -119.8264...  [pickup, delivery]
# 10  {'latitude': 36.8131166270708, 'longitude': -1...  [pickup, delivery]
# 11  {'latitude': 36.7576313763857, 'longitude': -1...  [pickup, delivery]
# 12    {'latitude': 36.80758, 'longitude': -119.83229}          [delivery]
# 13  {'latitude': 36.809290606212876, 'longitude': ...  [pickup, delivery]
# 14  {'latitude': 36.8516087986778, 'longitude': -1...          [delivery]
# 15  {'latitude': 36.80964, 'longitude': -119.80789...  [pickup, delivery]
# 16    {'latitude': 36.740603, 'longitude': -119.7999}                  []
# 17  {'latitude': 33.37233876, 'longitude': -117.25...  [pickup, delivery]
# 18  {'latitude': 36.7573776245117, 'longitude': -1...  [pickup, delivery]
# 19  {'latitude': 36.8650556, 'longitude': -119.738...  [pickup, delivery]
#
#    price                                           location         phone  \
# 0      $  {'address1': '1585 N Palm Ave', 'address2': ''...  +15592373800
# 1     $$  {'address1': '734 W Bullard Ave', 'address2': ...  +15594395303
# 2     $$  {'address1': '585 W Nees Ave', 'address2': 'St...  +15592838915
# 3     $$  {'address1': '2095 W Bullard Ave', 'address2':...  +15598401564
# 4     $$  {'address1': '3173 W Shaw Ave', 'address2': 'S...  +15593657000
# 5      $  {'address1': '2792 Willow Ave', 'address2': No...  +15592945952
# 6     $$  {'address1': '8484 N Friant Rd', 'address2': '...  +15599818995
# 7    NaN  {'address1': '3795 N West Ave', 'address2': 'S...  +15593751680
# 8    NaN  {'address1': '3028 W Bullard Ave', 'address2':...  +15593190500
# 9     $$  {'address1': '3228 N West Ave 93705', 'address...  +15592292635
# 10    $$  {'address1': '5251 N Blackstone Ave', 'address...  +15593745390
# 11     $  {'address1': '844 E Olive', 'address2': '', 'a...  +15594410067
# 12   $$$  {'address1': '2257 W Shaw Ave', 'address2': ''...  +15592488512
# 13    $$  {'address1': '3050 W Shaw Ave', 'address2': 'S...  +15592773737
# 14    $$  {'address1': '7835 N Palm Ave', 'address2': 'S...  +15594356775
# 15    $$  {'address1': '5068 N Palm Ave', 'address2': ''...  +15592252574
# 16    $$  {'address1': '1755 Broadway St', 'address2': '...  +15597249356
# 17    $$  {'address1': '1125 S Mission Rd', 'address2': ...  +17606450505
# 18     $  {'address1': '444 E Olive Ave', 'address2': 'S...  +15592683494
# 19    $$  {'address1': '8887 N Chestnut Ave', 'address2'...  +15592981122
#
#      display_phone     distance
# 0   (559) 237-3800  4097.525055
# 1   (559) 439-5303  2505.821716
# 2   (559) 283-8915  5613.596878
# 3   (559) 840-1564  3286.502481
# 4   (559) 365-7000  4149.776354
# 5   (559) 294-5952  6648.725690
# 6   (559) 981-8995  6697.136344
# 7   (559) 375-1680  2725.519464
# 8   (559) 319-0500  4566.833325
# 9   (559) 229-2635  3199.781212
# 10  (559) 374-5390  1645.991131
# 11  (559) 441-0067  4837.217948
# 12  (559) 248-8512  2750.675700
# 13  (559) 277-3737  3911.465977
# 14  (559) 435-6775  5639.780396
# 15  (559) 225-2574  1072.271503
# 16  (559) 724-9356  6722.734739
# 17  (760) 645-0505  2973.004575
# 18  (559) 268-3494  4871.150638
# 19  (559) 298-1122  8991.277059
